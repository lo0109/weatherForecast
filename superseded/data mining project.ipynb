# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('weatherAUS.csv')

# %%
num_samples = df_data.shape[0]
numerical_attributes = data.select_dtypes(include=['float64', 'int64']).columns
categorical_attributes = data.select_dtypes(include=['object']).columns
numerical_summary = data[numerical_attributes].describe()
print(numerical_summary)
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df_data = data
df_data.head()
## pd.DataFrame(data)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df_data[['Year','Month', 'Day']] = data['Date'].str.rsplit('-',n=0,expand=True)

col = df_data.pop('Year')
col1 = df_data.pop('Month')
col2 = df_data.pop('Day')
df_data.insert(0, col.name, col)
df_data.insert(1, col1.name, col1)
df_data.insert(2, col2.name, col2)
df_data.drop('Date', axis=1, inplace = True)
df_data.head()
# Out:
#    Year Month Day Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008    12  01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008    12  02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008    12  03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008    12  04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008    12  05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  ...  Humidity9am Humidity3pm Pressure9am  Pressure3pm  \
# 0           W  ...         71.0        22.0      1007.7       1007.1
# 1         WNW  ...         44.0        25.0      1010.6       1007.8
# 2         WSW  ...         38.0        30.0      1007.6       1008.7
# 3          NE  ...         45.0        16.0      1017.6       1012.8
# 4           W  ...         82.0        33.0      1010.8       1006.0
#
#    Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow
# ...

# %%
df_weather = data
df_weather[['Year', 'Month', 'Day']] = data['Date'].str.rsplit('-',n=0,expand=True)
col = df_weather.pop('Year')
col1 = df_weather.pop('Month')
col2 = df_weather.pop('Day')
df_weather.insert(0, col.name, col)
df_weather.insert(1, col1.name, col1)
df_weather.insert(2, col2.name, col2)
df_weather.drop('Date', axis=1, inplace = True)
df_weather.head()
# Out:
#    Year Month Day Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008    12  01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008    12  02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008    12  03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008    12  04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008    12  05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  ...  Humidity9am Humidity3pm Pressure9am  Pressure3pm  \
# 0           W  ...         71.0        22.0      1007.7       1007.1
# 1         WNW  ...         44.0        25.0      1010.6       1007.8
# 2         WSW  ...         38.0        30.0      1007.6       1008.7
# 3          NE  ...         45.0        16.0      1017.6       1012.8
# 4           W  ...         82.0        33.0      1010.8       1006.0
#
#    Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow
# ...

# %%
df_mintemp= pd.DataFrame(df_weather.groupby(['Year', 'Month'])['MinTemp'].mean())
df_mintemp
# Out:
#               MinTemp
# Year Month
# 2007 11     11.753333
#      12     13.312903
# 2008 01     15.348387
#      02     15.601724
#      03     14.116129
# ...               ...
# 2017 02     17.155188
#      03     17.014684
#      04     12.376552
#      05      9.521873
#      06      7.145840
#
# [113 rows x 1 columns]

# %%
df_weather['MinTemp'] = df_weather.groupby(['Year','Month'], sort=False)['MinTemp'].apply(lambda x: x.fillna(x.mean()))
# Out:
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_77233/1627540136.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather['MinTemp'] = df_weather.groupby(['Year','Month'], sort=False)['MinTemp'].apply(lambda x: x.fillna(x.mean()))

# %%
## https://www.analyticsvidhya.com/blog/2021/06/predictive-modelling-rain-prediction-in-australia-with-python/
## get rid of outliers
df_test = data
outliers = ['MinTemp', 'MaxTemp','Humidity9am', 'Pressure9am', 'Pressure3pm', 'Temp9am', 'Temp3pm']
for o in outliers:
    q1 = df_test[o].quantile(0.25)
    q3 = df_test[o].quantile(0.75)
    IQR = q3-q1
    lower_limit = q1 - (IQR*1.5)
    upper_limit = q3 + (IQR*1.5)
    df_test.loc[df_test[o]<lower_limit,o] = lower_limit
    df_test.loc[df_test[o]>upper_limit,o] = upper_limit
df_test.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194186      23.224781       2.360918      5.468232
# std         6.397741       7.100632       8.478060      4.193704
# min        -6.350000       2.450000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        30.850000      43.650000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df_diff = pd.concat([df_weather,df_data]).drop_duplicates(keep=False)
df_diff
# Out:
#         Year Month Day Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 12      2008    12  13   Albury     15.9     18.6      15.6          NaN
# 44      2009    01  14   Albury     17.4     43.0       0.0          NaN
# 52      2009    01  22   Albury     24.4     34.0       0.6          NaN
# 60      2009    01  30   Albury     22.3     42.9       0.0          NaN
# 61      2009    01  31   Albury     22.0     42.7       0.0          NaN
# ...      ...   ...  ..      ...      ...      ...       ...          ...
# 145280  2016    12  28    Uluru     22.6     36.8       0.0          NaN
# 145335  2017    02  21    Uluru     13.5      NaN       0.0          NaN
# 145342  2017    02  28    Uluru     15.9     38.2       0.0          NaN
# 145353  2017    03  11    Uluru     22.0     37.4       0.0          NaN
# 145459  2017    06  25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  ...  Humidity9am Humidity3pm Pressure9am  \
# ...

# %%
df = pd.DataFrame({
    'group': ['A', 'A', 'B', 'B', 'B', 'C', 'C'],
    'value': [10, 20, 30, 40, 50, 60, 70]
})

# define a function to remove outliers
def remove_outliers(group):
    q1 = group['value'].quantile(0.25)
    q3 = group['value'].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    
    return (group['value'] > lower_bound) & (group['value'] < upper_bound)

# apply the function to each group using transform
cleaned_df = df[ df.groupby('group')['value'].transform(remove_outliers) ]
cleaned_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:146, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:49, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[166], line 17
# ...

# %%
## https://devskrol.com/2020/08/09/best-way-to-impute-nan-within-groups-mean-mode/
## replace the NA with monthly mean
list_has_int = ['MinTemp', 'MaxTemp', 'Humidity9am' , 'Humidity3pm' , 'Pressure9am', 'Pressure3pm','Temp9am' , 'Temp3pm']
for i in list_has_int:
    df_weather[i] = df_weather.groupby(['Year','Month'], sort=False)[i].apply(lambda x: x.fillna(x.mean()))
# Out:
# MinTemp
# MaxTemp
# Humidity9am
# Humidity3pm
# Pressure9am
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_77233/207997538.py:6: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[i] = df_weather.groupby(['Year','Month'], sort=False)[i].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_77233/207997538.py:6: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# ...

# %%
missing_values = df_weather.isnull().sum()
missing_values
# Out:
# Year                 0
# Month                0
# Day                  0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am          0
# Humidity3pm          0
# Pressure9am          0
# Pressure3pm          0
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am              0
# Temp3pm              0
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df_weather.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  145460.000000  145460.000000  142199.000000  82670.000000
# mean       12.199921      23.232544       2.360918      5.468232
# std         6.377840       7.083407       8.478060      4.193704
# min        -6.350000       2.450000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        30.850000      43.650000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df_ori_mean = pd.DataFrame(df_weather.groupby(['Year', 'Month'])['MinTemp', 'MaxTemp', 'Humidity9am' , 'Humidity3pm' , 'Pressure9am', 'Pressure3pm','Temp9am' , 'Temp3pm'].mean())
df_new_mean = pd.DataFrame(df_weather.groupby(['Year', 'Month'])['MinTemp', 'MaxTemp', 'Humidity9am' , 'Humidity3pm' , 'Pressure9am', 'Pressure3pm','Temp9am' , 'Temp3pm'].mean())
# Out:
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_77233/720936449.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_ori_mean = pd.DataFrame(df_weather.groupby(['Year', 'Month'])['MinTemp', 'MaxTemp', 'Humidity9am' , 'Humidity3pm' , 'Pressure9am', 'Pressure3pm','Temp9am' , 'Temp3pm'].mean())
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_77233/720936449.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_new_mean = pd.DataFrame(df_weather.groupby(['Year', 'Month'])['MinTemp', 'MaxTemp', 'Humidity9am' , 'Humidity3pm' , 'Pressure9am', 'Pressure3pm','Temp9am' , 'Temp3pm'].mean())

# %%
df_diff = pd.concat([df_ori_mean,df_new_mean]).drop_duplicates(keep=False)
df_diff
# Out:
# Empty DataFrame
# Columns: [MinTemp, MaxTemp, Humidity9am, Humidity3pm, Pressure9am, Pressure3pm, Temp9am, Temp3pm]
# Index: []

# %%
df_weather['Category_Column'] = df_train['Category_Column'].fillna(df_train.groupby('Dependent_Column')['Number_Weeks_Used'].transform('mode'))
df_train['Number_Weeks_Used'] = df_train['Number_Weeks_Used'].fillna(df_train.groupby('Pesticide_Use_Category')['Number_Weeks_Used'].transform('mean'))
