# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
/#read the csv file into data frame
df = pd.read_csv('weatherAUS.csv')
print("The Dataset consists of: ", df.shape[0], " rows and ", df.shape[1], " columuns")
df.head(10)
# Out:
# The Dataset consists of:  145460  rows and  23  columuns
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8  2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9  2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
# 5         WNW           56.0          W  ...        55.0         23.0
# 6           W           50.0         SW  ...        49.0         19.0
# 7           W           35.0        SSE  ...        48.0         19.0
# 8         NNW           80.0         SE  ...        42.0          9.0
# 9           W           28.0          S  ...        58.0         27.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
# 5       1009.2       1005.4       NaN       NaN     20.6     28.9         No
# 6       1009.6       1008.2       1.0       NaN     18.1     24.6         No
# 7       1013.4       1010.1       NaN       NaN     16.3     25.5         No
# 8       1008.9       1003.6       NaN       NaN     18.3     30.2         No
# 9       1007.0       1005.7       NaN       NaN     20.1     28.2        Yes
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
# 5            No
# 6            No
# 7            No
# 8           Yes
# 9            No
#
# [10 rows x 23 columns]

# %%
#describe the data
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.800000      31.000000       7.000000      13.000000
# 50%        8.400000      39.000000      13.000000      19.000000
# 75%       10.600000      48.000000      19.000000      24.000000
# max       14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm   Pressure9am    Pressure3pm  \
# count  142806.000000  140953.000000  130395.00000  130432.000000
# mean       68.880831      51.539116    1017.64994    1015.255889
# std        19.029164      20.795902       7.10653       7.037414
# min         0.000000       0.000000     980.50000     977.100000
# 25%        57.000000      37.000000    1012.90000    1010.400000
# 50%        70.000000      52.000000    1017.60000    1015.200000
# 75%        83.000000      66.000000    1022.40000    1020.000000
# max       100.000000     100.000000    1041.00000    1039.600000
#
#            Cloud9am      Cloud3pm        Temp9am       Temp3pm
# count  89572.000000  86102.000000  143693.000000  141851.00000
# mean       4.447461      4.509930      16.990631      21.68339
# std        2.887159      2.720357       6.488753       6.93665
# min        0.000000      0.000000      -7.200000      -5.40000
# 25%        1.000000      2.000000      12.300000      16.60000
# 50%        5.000000      5.000000      16.700000      21.10000
# 75%        7.000000      7.000000      21.600000      26.40000
# max        9.000000      9.000000      40.200000      46.70000

# %%
#checking the data types of each columns
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
#total missing values ineach column of the data
missing_values = df.isnull().sum()
missing_values
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
# Check the percentage of missing values in each column
missing_percentage = (missing_values / len(df)) * 100
missing_percentage
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020899
# MaxTemp           0.866905
# Rainfall          2.241853
# Evaporation      43.166506
# Sunshine         48.009762
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Cloud9am         38.421559
# Cloud3pm         40.807095
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
categorical_features = [column_name for column_name in df.columns if df[column_name].dtype == 'O']
print("Number of Categorical Features: {}".format(len(categorical_features)))
print("Categorical Features: ",categorical_features)
# Out:
# Number of Categorical Features: 7
# Categorical Features:  ['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %%
numerical_features = [column_name for column_name in df.columns if df[column_name].dtype != 'O']
print("Number of Numerical Features: {}".format(len(numerical_features)))
print("Numerical Features: ",numerical_features)
# Out:
# Number of Numerical Features: 16
# Numerical Features:  ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']

# %%
## split the Date column in Year Month Day
df_weather = df
df_weather[['Year', 'Month', 'Day']] = df['Date'].str.rsplit('-',n=0,expand=True)
col = df_weather.pop('Year')
col1 = df_weather.pop('Month')
col2 = df_weather.pop('Day')
df_weather.insert(0, col.name, col)
df_weather.insert(1, col1.name, col1)
df_weather.insert(2, col2.name, col2)
df_weather.drop('Date', axis=1, inplace = True)
df_weather.head()
# Out:
#    Year Month Day Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008    12  01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008    12  02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008    12  03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008    12  04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008    12  05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  ...  Humidity9am Humidity3pm Pressure9am  Pressure3pm  \
# 0           W  ...         71.0        22.0      1007.7       1007.1
# 1         WNW  ...         44.0        25.0      1010.6       1007.8
# 2         WSW  ...         38.0        30.0      1007.6       1008.7
# 3          NE  ...         45.0        16.0      1017.6       1012.8
# 4           W  ...         82.0        33.0      1010.8       1006.0
#
#    Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow
# 0       8.0       NaN     16.9     21.8         No            No
# 1       NaN       NaN     17.2     24.3         No            No
# 2       NaN       2.0     21.0     23.2         No            No
# 3       NaN       NaN     18.1     26.5         No            No
# 4       7.0       8.0     17.8     29.7         No            No
#
# [5 rows x 25 columns]

# %%
##https://www.geeksforgeeks.org/rainfall-prediction-using-machine-learning-python/
plt.subplots(figsize=(15,8))
 
for i, col in enumerate(numerical_features):
  plt.subplot(3,4, i + 1)
  sns.boxplot(df_weather[col])
plt.tight_layout()
plt.show()
# Out:
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/608622611.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,4, i + 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 plt.subplots(figsize=(15,8))
#       3 for i, col in enumerate(numerical_features):
# ----> 4   plt.subplot(3,4, i + 1)
#       5   sns.boxplot(df_weather[col])
#       6 plt.tight_layout()
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:1323, in subplot(*args, **kwargs)
#    1320 fig = gcf()
#    1322 # First, search for an existing subplot with a matching spec.
# -> 1323 key = SubplotSpec._from_subplot_args(fig, args)
#    1325 for ax in fig.axes:
#    1326     # if we found an Axes at the position sort out if we can re-use it
#    1327     if ax.get_subplotspec() == key:
#    1328         # if the user passed no kwargs, re-use
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/gridspec.py:598, in SubplotSpec._from_subplot_args(figure, args)
#     596 else:
#     597     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 598         raise ValueError(
#     599             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     600             f"not {num!r}"
#     601         )
#     602     i = j = num
#     603 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 12, not 13

# %%
## https://www.analyticsvidhya.com/blog/2021/06/predictive-modelling-rain-prediction-in-australia-with-python/
## get rid of outliers
## 'Rainfall','Evaporation','Sunshine' are not included
outliers = ['MinTemp', 'MaxTemp','Humidity9am', 'Pressure9am', 'Pressure3pm', 'Temp9am', 'Temp3pm']
for o in outliers:
    q1 = df_weather[o].quantile(0.25)
    q3 = df_weather[o].quantile(0.75)
    IQR = q3-q1
    lower_limit = q1 - (IQR*1.5)
    upper_limit = q3 + (IQR*1.5)
    df_weather.loc[df_weather[o]<lower_limit,o] = lower_limit
    df_weather.loc[df_weather[o]>upper_limit,o] = upper_limit
df_weather.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194186      23.224781       2.360918      5.468232
# std         6.397741       7.100632       8.478060      4.193704
# min        -6.350000       2.450000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        30.850000      43.650000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.800000      31.000000       7.000000      13.000000
# 50%        8.400000      39.000000      13.000000      19.000000
# 75%       10.600000      48.000000      19.000000      24.000000
# max       14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm    Pressure9am    Pressure3pm  \
# count  142806.000000  140953.000000  130395.000000  130432.000000
# mean       68.933567      51.539116    1017.670297    1015.269781
# std        18.876608      20.795902       7.025447       6.976954
# min        18.000000       0.000000     998.650000     996.000000
# 25%        57.000000      37.000000    1012.900000    1010.400000
# 50%        70.000000      52.000000    1017.600000    1015.200000
# 75%        83.000000      66.000000    1022.400000    1020.000000
# max       100.000000     100.000000    1036.650000    1034.400000
#
#            Cloud9am      Cloud3pm        Temp9am        Temp3pm
# count  89572.000000  86102.000000  143693.000000  141851.000000
# mean       4.447461      4.509930      16.991728      21.686191
# std        2.887159      2.720357       6.481325       6.909048
# min        0.000000      0.000000      -1.650000       1.900000
# 25%        1.000000      2.000000      12.300000      16.600000
# 50%        5.000000      5.000000      16.700000      21.100000
# 75%        7.000000      7.000000      21.600000      26.400000
# max        9.000000      9.000000      35.550000      41.100000

# %%
##https://www.geeksforgeeks.org/rainfall-prediction-using-machine-learning-python/
##show the data corresponding to RainToday
df_weather.groupby('RainToday').mean()
## rainfall, humidity, sunshine, evaporation, cloud and temp are related to RainToday
# Out:
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/733983650.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_weather.groupby('RainToday').mean()
#              MinTemp    MaxTemp   Rainfall  Evaporation  Sunshine  \
# RainToday
# No         11.994453  24.106430   0.075248     5.890936  8.301538
# Yes        12.851973  20.207981  10.270354     3.995899  5.313555
#
#            WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# RainToday
# No             38.855081     13.507234     18.255793    65.301079
# Yes            43.950805     15.706089     19.958615    81.413609
#
#            Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# RainToday
# No           47.253270  1018.382040  1015.663483  3.942562  4.089155
# Yes          66.191317  1015.220909  1013.912883  6.019534  5.827370
#
#              Temp9am    Temp3pm
# RainToday
# No         17.324495  22.563813
# Yes        15.819845  18.660678

# %%
## https://devskrol.com/2020/08/09/best-way-to-impute-nan-within-groups-mean-mode/
## replace the missing data with monthly mean
list_has_int = ['MinTemp', 'MaxTemp', 'Pressure9am', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Pressure3pm']
for i in list_has_int:
    df_weather[i] = df_weather.groupby(['Year','Month'], sort=False)[i].apply(lambda x: x.fillna(x.mean()))

## replace the missing data related to rainfall with monthly mean
list_rain = ['Rainfall', 'Evaporation','Humidity9am' , 'Humidity3pm', 'Sunshine' , 'Cloud9am', 'Cloud3pm', 'Temp9am' , 'Temp3pm']
for r in list_rain:
    df_weather[r] = df_weather.groupby(['Year','Month','RainToday'], sort=False)[r].apply(lambda x: x.fillna(x.mean()))
    
df_weather.describe()
# Out:
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:5: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[i] = df_weather.groupby(['Year','Month'], sort=False)[i].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:5: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[i] = df_weather.groupby(['Year','Month'], sort=False)[i].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:5: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[i] = df_weather.groupby(['Year','Month'], sort=False)[i].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:5: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[i] = df_weather.groupby(['Year','Month'], sort=False)[i].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:5: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[i] = df_weather.groupby(['Year','Month'], sort=False)[i].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:5: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[i] = df_weather.groupby(['Year','Month'], sort=False)[i].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:5: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[i] = df_weather.groupby(['Year','Month'], sort=False)[i].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:10: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[r] = df_weather.groupby(['Year','Month','RainToday'], sort=False)[r].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:10: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[r] = df_weather.groupby(['Year','Month','RainToday'], sort=False)[r].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:10: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[r] = df_weather.groupby(['Year','Month','RainToday'], sort=False)[r].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:10: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[r] = df_weather.groupby(['Year','Month','RainToday'], sort=False)[r].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:10: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[r] = df_weather.groupby(['Year','Month','RainToday'], sort=False)[r].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:10: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[r] = df_weather.groupby(['Year','Month','RainToday'], sort=False)[r].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:10: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[r] = df_weather.groupby(['Year','Month','RainToday'], sort=False)[r].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:10: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[r] = df_weather.groupby(['Year','Month','RainToday'], sort=False)[r].apply(lambda x: x.fillna(x.mean()))
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/2566216548.py:10: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_weather[r] = df_weather.groupby(['Year','Month','RainToday'], sort=False)[r].apply(lambda x: x.fillna(x.mean()))
#              MinTemp        MaxTemp       Rainfall    Evaporation  \
# count  145460.000000  145460.000000  142199.000000  142199.000000
# mean       12.199922      23.232564       2.360918       5.531634
# std         6.377838       7.083371       8.478060       3.544509
# min        -6.350000       2.450000       0.000000       0.000000
# 25%         7.600000      17.900000       0.000000       3.046250
# 50%        12.000000      22.600000       0.000000       5.000000
# 75%        16.900000      28.200000       0.800000       7.549538
# max        30.850000      43.650000     371.000000     145.000000
#
#             Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  142199.000000  145460.000000  145460.000000  145460.000000
# mean        7.628297      40.043844      14.046102      18.666449
# std         2.985078      13.150918       8.862473       8.720535
# min         0.000000       6.000000       0.000000       0.000000
# 25%         6.012178      31.000000       7.000000      13.000000
# 50%         8.000000      39.000000      13.000000      19.000000
# 75%         9.700000      46.000000      19.000000      24.000000
# max        14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm    Pressure9am    Pressure3pm  \
# count  142199.000000  142199.000000  145460.000000  145460.000000
# mean       68.924455      51.502666    1017.673584    1015.272961
# std        18.821155      20.597048       6.744476       6.694959
# min        18.000000       0.000000     998.650000     996.000000
# 25%        57.000000      37.000000    1013.300000    1010.900000
# 50%        70.000000      52.000000    1017.600000    1015.200000
# 75%        83.000000      65.000000    1022.100000    1019.600000
# max       100.000000     100.000000    1036.650000    1034.400000
#
#             Cloud9am       Cloud3pm        Temp9am        Temp3pm
# count  142199.000000  142199.000000  142199.000000  142199.000000
# mean        4.419542       4.489578      16.987384      21.696286
# std         2.348400       2.168605       6.479800       6.873480
# min         0.000000       0.000000      -1.650000       1.900000
# 25%         3.000000       3.299501      12.300000      16.600000
# 50%         4.286567       4.392537      16.700000      21.100000
# 75%         6.392905       6.000000      21.600000      26.400000
# max         9.000000       9.000000      35.550000      41.100000

# %%
##https://www.geeksforgeeks.org/rainfall-prediction-using-machine-learning-python/
plt.pie(df_weather['RainToday'].value_counts().values,
        labels = df_weather['RainToday'].value_counts().index,
        autopct='%1.1f%%')
plt.show()

# %%
##https://www.geeksforgeeks.org/rainfall-prediction-using-machine-learning-python/
df_weather['RainToday'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Out:
# /var/folders/kz/36nj487d0sgbg74v1kmzvdmc0000gn/T/ipykernel_12095/3474251287.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_weather.groupby('RainToday').mean()
#              MinTemp    MaxTemp   Rainfall  Evaporation  Sunshine  \
# RainToday
# No         11.995693  24.104852   0.075248     5.890936  8.301538
# Yes        12.847619  20.218921  10.270354     3.995899  5.313555
#
#            WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# RainToday
# No             38.855081     13.507234     18.255793    65.345931
# Yes            43.950805     15.706089     19.958615    81.264837
#
#            Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# RainToday
# No           47.356411  1018.314336  1015.625849  3.942562  4.089155
# Yes          65.772373  1015.463871  1014.049367  6.019534  5.827370
#
#              Temp9am    Temp3pm
# RainToday
# No         17.324355  22.554100
# Yes        15.822923  18.739616
